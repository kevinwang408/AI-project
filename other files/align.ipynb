# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset=pd.read_csv('SolarPrediction.csv',engine='python')
dataset.head(5)
# Out:
#      UNIXTime                   Data      Time  Radiation  Temperature  \
# 0  1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1  1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2  1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3  1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4  1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
#
#    Pressure  Humidity  WindDirection(Degrees)  Speed TimeSunRise TimeSunSet
# 0     30.46        59                  177.39   5.62    06:13:00   18:13:00
# 1     30.46        58                  176.78   3.37    06:13:00   18:13:00
# 2     30.46        57                  158.75   3.37    06:13:00   18:13:00
# 3     30.46        60                  137.71   3.37    06:13:00   18:13:00
# 4     30.46        62                  104.95   5.62    06:13:00   18:13:00

# %%
test=dataset.values
test2=dataset.values
test.shape
test2.shape
# Out:
# (32686, 11)

# %%
print(test[7416,:])
print(test[7417,:])
print(test2[7416,:])
print(test2[7417,:])
# Out:
# [1472724008 '9/1/2016 12:00:00 AM' '00:00:08' 2.58 51 30.43 103 77.27
#  11.25 '06:07:00' '18:38:00']
# [1477994117 '10/31/2016 12:00:00 AM' '23:55:17' 1.26 47 30.48 56 157.12
#  7.87 '06:23:00' '17:49:00']
# [1472724008 '9/1/2016 12:00:00 AM' '00:00:08' 2.58 51 30.43 103 77.27
#  11.25 '06:07:00' '18:38:00']
# [1477994117 '10/31/2016 12:00:00 AM' '23:55:17' 1.26 47 30.48 56 157.12
#  7.87 '06:23:00' '17:49:00']

# %%
i=0
for i in range(0,7417):
    test[i,:]=test2[7416-i,:]

# %%
test2=dataset.values

# %%
for i in range(7417,16238):
    test[i,:]=test2[16237-(i-7417),:]

# %%
test2=dataset.values

# %%
for i in range(16238,24522):
    test[i,:]=test2[24521-(i-16238),:]

# %%
test2=dataset.values

# %%
for i in range(24522,32686):
    test[i,:]=test2[32685-(i-24522),:]

# %%
print(test[7416,:])
print(test[7417,:])
print(test2[7416,:])
print(test2[7417,:])
# Out:
# [1475229326 '9/29/2016 12:00:00 AM' '23:55:26' 1.21 48 30.46 59 177.39
#  5.62 '06:13:00' '18:13:00']
# [1475316019 '10/1/2016 12:00:00 AM' '00:00:19' 1.27 48 30.46 79 137.68
#  11.25 '06:13:00' '18:11:00']
# [1472724008 '9/1/2016 12:00:00 AM' '00:00:08' 2.58 51 30.43 103 77.27
#  11.25 '06:07:00' '18:38:00']
# [1477994117 '10/31/2016 12:00:00 AM' '23:55:17' 1.26 47 30.48 56 157.12
#  7.87 '06:23:00' '17:49:00']

# %%
store=pd.DataFrame(test,columns=["UNIXTime","Data","Time","Radiation","Temperature","Pressure","Humidity","WindDirection(Degrees)","Speed","TimeSunRise","TimeSunSet"])
store.to_csv("SolarPrediction_aligned.csv",index=False)

# %%
len(test)
# Out:
# 32686

# %%
for i in range(0,len(test)-1):
    detect=test[i+1,0]-test[i,0]
    print(detect)
    if detect<0:
        print(i,"error")
        break
# Out:
# 302
# 896
# 299
# 304
# 895
# 302
# 298
# 303
# 298
# 301
# 308
# 289
# 303
# 302
# 296
# 303
# 301
# 335
# 261
# 301
# 300
# 304
# 294
# 305
# 298
# 300
# 304
# 299
# 295
# 303
# 297
# 601
# 301
# 300
# 302
# 304
# 293
# 302
# 301
# 299
# 297
# 308
# 292
# 303
# 296
# 301
# 300
# 299
# 300
# 301
# 303
# 301
# 299
# 298
# 306
# 294
# 304
# 297
# 299
# 299
# 303
# 598
# 300
# 307
# 595
# 300
# 303
# 296
# 304
# 297
# 602
# 299
# 300
# 300
# 598
# 300
# 303
# 296
# 300
# 900
# 300
# 602
# 298
# 899
# 302
# 301
# 297
# 301
# 301
# 303
# 599
# 603
# 297
# 299
# 298
# 303
# 301
# 298
# 304
# 297
# 899
# 300
# 302
# 297
# 299
# 303
# 900
# 301
# 295
# 299
# 303
# 300
# 600
# 601
# 301
# 297
# 304
# 300
# 596
# 303
# 302
# 295
# 604
# 296
# 602
# 598
# 301
# 903
# 298
# 297
# 303
# 301
# 296
# 306
# 300
# 297
# 598
# 301
# 301
# 299
# 300
# 298
# 305
# 295
# 301
# 298
# 305
# 300
# 296
# 602
# 298
# 305
# 298
# 298
# 302
# 303
# 593
# 304
# 601
# 298
# 301
# 304
# 297
# 295
# 303
# 301
# ...
