# %%
from hamcrest import none
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error
from tcn import TCN, tcn_full_summary
import predict
batch_size, time_steps, input_dim = none, 5, 9
dataset=pd.read_csv('SolarPrediction_aligned_Sun.csv',engine='python',nrows=576*15)
dataset=dataset.drop("Data",axis=1)
dataset=dataset.drop("Time",axis=1)
dataset.head(5)
# Out:
#    UNIXTime  Radiation  Temperature  Pressure  Humidity  \
# 0         8       2.58           51     30.43       103
# 1       310       2.83           51     30.43       103
# 2      1206       2.16           51     30.43       103
# 3      1505       2.21           51     30.43       103
# 4      1809       2.25           51     30.43       103
#
#    WindDirection(Degrees)  Speed  TimeSunRise  TimeSunSet
# 0                   77.27  11.25        22020       67080
# 1                  153.44   9.00        22020       67080
# 2                  142.04   7.87        22020       67080
# 3                  144.12  18.00        22020       67080
# 4                   67.42  11.25        22020       67080

# %%
dataset=dataset.values

# %% [markdown]
# 取出來的數字不知道為甚麼做%會一直變 ==
# 把值用一變數取出改為int再寫入
# 重複執行會重複扣==

# %%
# take=np.zeros(len(dataset))
# take=dataset[:,0]

# %%
# take[:]=take[:]-1472724000
# take

# %%
# for i in range(0,len(dataset)):
#     take[i]=take[i]%(60*60*24)

# print(dataset[0,0])

# %% [markdown]
# 把take寫回去

# %%
# dataset[:,0]=take
# print(dataset)

# %% [markdown]
# 之前用作存時間整理的

# %%
# store=pd.DataFrame(dataset,columns=["UNIXTime","Data","Time","Radiation","Temperature","Pressure","Humidity","WindDirection(Degrees)","Speed","TimeSunRise","TimeSunSet"])
# store.to_csv("SolarPrediction_time_aligned.csv",index=False)

# %% [markdown]
# 在這邊scalar會被設定為對七筆資料做scalar
# 導致最後輸出結果無法scalar回去
# 到後面分資料實在scalar
# 存有對輸出scalar的資料

# %%
dataset[:,1]
# Out:
# array([  2.58,   2.83,   2.16, ..., 344.9 , 365.66, 355.57])

# %%
dataset=dataset.astype('float32')

scalar1=MinMaxScaler(feature_range=(0,1))
scalar2=MinMaxScaler(feature_range=(0,1))
scalar_dim=dataset[:,1]
dataset=scalar1.fit_transform(dataset)

scalar_dim=scalar_dim.reshape(len(dataset),1)
print(scalar_dim)
scalar_dim=scalar2.fit_transform(scalar_dim)
print(scalar_dim)
# Out:
# [[  2.58]
#  [  2.83]
#  [  2.16]
#  ...
#  [344.9 ]
#  [365.66]
#  [355.57]]
# [[0.00089369]
#  [0.00104993]
#  [0.00063121]
#  ...
#  [0.21482898]
#  [0.2278031 ]
#  [0.22149728]]

# %%
train_size=int(len(dataset)*0.67)
test_size=len(dataset)- train_size
train,test=dataset[0:train_size,:],dataset[train_size:len(dataset),:]

print(train.shape)
print(train)
print(test.shape)
#print(test)
# Out:
# (5788, 9)
# [[5.8056499e-05 8.9368853e-04 3.3333325e-01 ... 5.5555558e-01
#   0.0000000e+00 1.0000000e+00]
#  [3.5646691e-03 1.0499278e-03 3.3333325e-01 ... 4.4444445e-01
#   0.0000000e+00 1.0000000e+00]
#  [1.3968393e-02 6.3120667e-04 3.3333325e-01 ... 3.8864198e-01
#   0.0000000e+00 1.0000000e+00]
#  ...
#  [1.7786188e-01 4.3747015e-05 2.6666665e-01 ... 2.2222222e-01
#   7.1428680e-01 2.9999924e-01]
#  [1.8134527e-01 5.6246121e-05 2.6666665e-01 ... 2.7753085e-01
#   7.1428680e-01 2.9999924e-01]
#  [1.8480544e-01 6.2495703e-05 2.6666665e-01 ... 2.2222222e-01
#   7.1428680e-01 2.9999924e-01]]
# (2852, 9)

# %% [markdown]
# 以下列的函式去執行
# 可以將每一筆資料對應前五個時間點及七筆資料
# 又有幾百筆資料做對應
# 故會有三為資料
# 注 在這邊分成target及分析內容

# %%
def create_dataset(dataset,look_back):
    dataX,dataY=[],[]
    for i in range(len(dataset)-look_back-1):
        #a=dataset第0行i~i+look_back個
        a=dataset[i:(i+look_back),0:9]
        dataX.append(a)
        dataY.append(dataset[i+look_back,1])
    return np.array(dataX),np.array(dataY)

# %%
#根據前面幾個資料來看下一步 彙整成look_back行的資料
#X用以輸入 Y用用以predict
look_back=5
trainX,trainY=create_dataset(train,look_back)
testX,testY=create_dataset(test,look_back)
print(testX.shape)
#print(testX)
print(testY.shape)
print(trainX.shape)
print(trainY.shape)
# Out:
# (2846, 5, 9)
# (2846,)
# (5782, 5, 9)
# (5782,)

# %% [markdown]
# TCN test

# %%
#tcn_layer = TCN(nb_filters=64,kernel_size=3,dropout_rate=0.0,padding='causal',activation='relu',input_shape=(time_steps, input_dim))
#tcn_layer = TCN(nb_filters=97,kernel_size=8,input_shape=(time_steps, input_dim))
tcn_layer = TCN(nb_filters=110,
                kernel_size=10,
                dropout_rate=0.1331163281069671,
                activation='relu',padding='causal',
                nb_stacks=1,
                dilations=(1, 2, 4, 8, 16),
                input_shape=(time_steps, input_dim))
print('Receptive field size =', tcn_layer.receptive_field)

model = Sequential([tcn_layer,Dense(64),Dense(1)])
model.compile(optimizer='adam', loss='mse')
tcn_full_summary(model, expand_residual_blocks=False)
# Out:
# Receptive field size = 559
# WARNING: tcn_full_summary: Compatible with tensorflow 2.5.0 or below.
# Use tensorboard instead. Example in keras-tcn/tasks/tcn_tensorboard.py.

# %%
model.fit(trainX, trainY, epochs=150,verbose=2)
# Out:
# Epoch 1/150
# 181/181 - 11s - loss: 0.0627 - 11s/epoch - 59ms/step
# Epoch 2/150
# 181/181 - 7s - loss: 0.0058 - 7s/epoch - 39ms/step
# Epoch 3/150
# 181/181 - 7s - loss: 0.0049 - 7s/epoch - 39ms/step
# Epoch 4/150
# 181/181 - 7s - loss: 0.0047 - 7s/epoch - 38ms/step
# Epoch 5/150
# 181/181 - 7s - loss: 0.0043 - 7s/epoch - 39ms/step
# Epoch 6/150
# 181/181 - 7s - loss: 0.0041 - 7s/epoch - 38ms/step
# Epoch 7/150
# 181/181 - 7s - loss: 0.0042 - 7s/epoch - 40ms/step
# Epoch 8/150
# 181/181 - 7s - loss: 0.0040 - 7s/epoch - 37ms/step
# Epoch 9/150
# 181/181 - 7s - loss: 0.0039 - 7s/epoch - 38ms/step
# Epoch 10/150
# 181/181 - 7s - loss: 0.0038 - 7s/epoch - 38ms/step
# Epoch 11/150
# 181/181 - 7s - loss: 0.0040 - 7s/epoch - 38ms/step
# Epoch 12/150
# 181/181 - 7s - loss: 0.0039 - 7s/epoch - 39ms/step
# Epoch 13/150
# 181/181 - 7s - loss: 0.0039 - 7s/epoch - 37ms/step
# Epoch 14/150
# 181/181 - 7s - loss: 0.0039 - 7s/epoch - 39ms/step
# Epoch 15/150
# 181/181 - 7s - loss: 0.0042 - 7s/epoch - 37ms/step
# Epoch 16/150
# 181/181 - 7s - loss: 0.0036 - 7s/epoch - 40ms/step
# Epoch 17/150
# 181/181 - 7s - loss: 0.0037 - 7s/epoch - 38ms/step
# Epoch 18/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 38ms/step
# Epoch 19/150
# 181/181 - 7s - loss: 0.0036 - 7s/epoch - 39ms/step
# Epoch 20/150
# 181/181 - 7s - loss: 0.0036 - 7s/epoch - 37ms/step
# Epoch 21/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 40ms/step
# Epoch 22/150
# 181/181 - 7s - loss: 0.0037 - 7s/epoch - 37ms/step
# Epoch 23/150
# 181/181 - 7s - loss: 0.0037 - 7s/epoch - 39ms/step
# Epoch 24/150
# 181/181 - 7s - loss: 0.0038 - 7s/epoch - 37ms/step
# Epoch 25/150
# 181/181 - 7s - loss: 0.0037 - 7s/epoch - 39ms/step
# Epoch 26/150
# 181/181 - 7s - loss: 0.0038 - 7s/epoch - 39ms/step
# Epoch 27/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 37ms/step
# Epoch 28/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 39ms/step
# Epoch 29/150
# 181/181 - 7s - loss: 0.0037 - 7s/epoch - 37ms/step
# Epoch 30/150
# 181/181 - 7s - loss: 0.0034 - 7s/epoch - 39ms/step
# Epoch 31/150
# 181/181 - 9s - loss: 0.0035 - 9s/epoch - 49ms/step
# Epoch 32/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 39ms/step
# Epoch 33/150
# 181/181 - 7s - loss: 0.0035 - 7s/epoch - 38ms/step
# Epoch 34/150
# 181/181 - 7s - loss: 0.0033 - 7s/epoch - 38ms/step
# Epoch 35/150
# 181/181 - 7s - loss: 0.0036 - 7s/epoch - 40ms/step
# Epoch 36/150
# 181/181 - 7s - loss: 0.0034 - 7s/epoch - 38ms/step
# Epoch 37/150
# 181/181 - 7s - loss: 0.0033 - 7s/epoch - 40ms/step
# Epoch 38/150
# 181/181 - 7s - loss: 0.0034 - 7s/epoch - 39ms/step
# Epoch 39/150
# 181/181 - 7s - loss: 0.0033 - 7s/epoch - 40ms/step
# Epoch 40/150
# 181/181 - 7s - loss: 0.0033 - 7s/epoch - 38ms/step
# Epoch 41/150
# 181/181 - 7s - loss: 0.0031 - 7s/epoch - 40ms/step
# Epoch 42/150
# 181/181 - 7s - loss: 0.0031 - 7s/epoch - 39ms/step
# Epoch 43/150
# 181/181 - 7s - loss: 0.0030 - 7s/epoch - 40ms/step
# Epoch 44/150
# 181/181 - 9s - loss: 0.0031 - 9s/epoch - 52ms/step
# Epoch 45/150
# 181/181 - 7s - loss: 0.0030 - 7s/epoch - 39ms/step
# Epoch 46/150
# 181/181 - 7s - loss: 0.0031 - 7s/epoch - 39ms/step
# Epoch 47/150
# 181/181 - 7s - loss: 0.0029 - 7s/epoch - 38ms/step
# Epoch 48/150
# 181/181 - 8s - loss: 0.0028 - 8s/epoch - 45ms/step
# Epoch 49/150
# 181/181 - 7s - loss: 0.0030 - 7s/epoch - 38ms/step
# Epoch 50/150
# 181/181 - 7s - loss: 0.0030 - 7s/epoch - 40ms/step
# Epoch 51/150
# 181/181 - 7s - loss: 0.0029 - 7s/epoch - 37ms/step
# Epoch 52/150
# 181/181 - 9s - loss: 0.0028 - 9s/epoch - 51ms/step
# Epoch 53/150
# 181/181 - 7s - loss: 0.0027 - 7s/epoch - 38ms/step
# Epoch 54/150
# 181/181 - 7s - loss: 0.0028 - 7s/epoch - 39ms/step
# Epoch 55/150
# 181/181 - 7s - loss: 0.0027 - 7s/epoch - 38ms/step
# Epoch 56/150
# 181/181 - 7s - loss: 0.0026 - 7s/epoch - 38ms/step
# Epoch 57/150
# 181/181 - 7s - loss: 0.0025 - 7s/epoch - 39ms/step
# Epoch 58/150
# 181/181 - 7s - loss: 0.0024 - 7s/epoch - 38ms/step
# Epoch 59/150
# 181/181 - 7s - loss: 0.0024 - 7s/epoch - 40ms/step
# Epoch 60/150
# 181/181 - 7s - loss: 0.0026 - 7s/epoch - 37ms/step
# Epoch 61/150
# 181/181 - 7s - loss: 0.0024 - 7s/epoch - 40ms/step
# Epoch 62/150
# 181/181 - 9s - loss: 0.0023 - 9s/epoch - 50ms/step
# Epoch 63/150
# 181/181 - 8s - loss: 0.0026 - 8s/epoch - 45ms/step
# Epoch 64/150
# 181/181 - 7s - loss: 0.0022 - 7s/epoch - 38ms/step
# Epoch 65/150
# 181/181 - 7s - loss: 0.0024 - 7s/epoch - 39ms/step
# Epoch 66/150
# 181/181 - 7s - loss: 0.0023 - 7s/epoch - 39ms/step
# Epoch 67/150
# 181/181 - 7s - loss: 0.0021 - 7s/epoch - 39ms/step
# Epoch 68/150
# 181/181 - 7s - loss: 0.0021 - 7s/epoch - 39ms/step
# Epoch 69/150
# 181/181 - 7s - loss: 0.0020 - 7s/epoch - 38ms/step
# Epoch 70/150
# 181/181 - 7s - loss: 0.0021 - 7s/epoch - 39ms/step
# Epoch 71/150
# 181/181 - 7s - loss: 0.0021 - 7s/epoch - 38ms/step
# Epoch 72/150
# 181/181 - 10s - loss: 0.0020 - 10s/epoch - 57ms/step
# Epoch 73/150
# 181/181 - 7s - loss: 0.0020 - 7s/epoch - 38ms/step
# Epoch 74/150
# 181/181 - 7s - loss: 0.0020 - 7s/epoch - 40ms/step
# Epoch 75/150
# 181/181 - 7s - loss: 0.0019 - 7s/epoch - 37ms/step
# Epoch 76/150
# 181/181 - 7s - loss: 0.0020 - 7s/epoch - 39ms/step
# Epoch 77/150
# 181/181 - 7s - loss: 0.0018 - 7s/epoch - 38ms/step
# Epoch 78/150
# 181/181 - 7s - loss: 0.0018 - 7s/epoch - 41ms/step
# Epoch 79/150
# 181/181 - 10s - loss: 0.0018 - 10s/epoch - 55ms/step
# Epoch 80/150
# 181/181 - 7s - loss: 0.0018 - 7s/epoch - 39ms/step
# Epoch 81/150
# 181/181 - 7s - loss: 0.0017 - 7s/epoch - 38ms/step
# Epoch 82/150
# 181/181 - 7s - loss: 0.0017 - 7s/epoch - 38ms/step
# Epoch 83/150
# 181/181 - 7s - loss: 0.0017 - 7s/epoch - 39ms/step
# Epoch 84/150
# 181/181 - 7s - loss: 0.0017 - 7s/epoch - 36ms/step
# Epoch 85/150
# 181/181 - 7s - loss: 0.0016 - 7s/epoch - 39ms/step
# Epoch 86/150
# 181/181 - 9s - loss: 0.0016 - 9s/epoch - 48ms/step
# Epoch 87/150
# 181/181 - 7s - loss: 0.0015 - 7s/epoch - 39ms/step
# Epoch 88/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 37ms/step
# Epoch 89/150
# 181/181 - 7s - loss: 0.0015 - 7s/epoch - 39ms/step
# Epoch 90/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 37ms/step
# Epoch 91/150
# 181/181 - 7s - loss: 0.0015 - 7s/epoch - 38ms/step
# Epoch 92/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 39ms/step
# Epoch 93/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 37ms/step
# Epoch 94/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 39ms/step
# Epoch 95/150
# 181/181 - 9s - loss: 0.0014 - 9s/epoch - 49ms/step
# Epoch 96/150
# 181/181 - 7s - loss: 0.0013 - 7s/epoch - 40ms/step
# Epoch 97/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 37ms/step
# Epoch 98/150
# 181/181 - 7s - loss: 0.0014 - 7s/epoch - 39ms/step
# Epoch 99/150
# 181/181 - 7s - loss: 0.0013 - 7s/epoch - 38ms/step
# Epoch 100/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 38ms/step
# Epoch 101/150
# 181/181 - 7s - loss: 0.0013 - 7s/epoch - 38ms/step
# Epoch 102/150
# 181/181 - 7s - loss: 0.0013 - 7s/epoch - 37ms/step
# Epoch 103/150
# 181/181 - 9s - loss: 0.0013 - 9s/epoch - 51ms/step
# Epoch 104/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 37ms/step
# Epoch 105/150
# 181/181 - 7s - loss: 0.0013 - 7s/epoch - 39ms/step
# Epoch 106/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 36ms/step
# Epoch 107/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 38ms/step
# Epoch 108/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 38ms/step
# Epoch 109/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 38ms/step
# Epoch 110/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 38ms/step
# Epoch 111/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 37ms/step
# Epoch 112/150
# 181/181 - 9s - loss: 0.0012 - 9s/epoch - 51ms/step
# Epoch 113/150
# 181/181 - 7s - loss: 0.0012 - 7s/epoch - 38ms/step
# Epoch 114/150
# 181/181 - 8s - loss: 0.0010 - 8s/epoch - 43ms/step
# Epoch 115/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 38ms/step
# Epoch 116/150
# 181/181 - 7s - loss: 0.0010 - 7s/epoch - 38ms/step
# Epoch 117/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 38ms/step
# Epoch 118/150
# 181/181 - 7s - loss: 0.0010 - 7s/epoch - 39ms/step
# Epoch 119/150
# 181/181 - 7s - loss: 9.7259e-04 - 7s/epoch - 38ms/step
# Epoch 120/150
# 181/181 - 7s - loss: 9.9755e-04 - 7s/epoch - 37ms/step
# Epoch 121/150
# 181/181 - 9s - loss: 0.0010 - 9s/epoch - 50ms/step
# Epoch 122/150
# 181/181 - 7s - loss: 0.0010 - 7s/epoch - 37ms/step
# Epoch 123/150
# 181/181 - 7s - loss: 0.0010 - 7s/epoch - 38ms/step
# Epoch 124/150
# 181/181 - 7s - loss: 8.9995e-04 - 7s/epoch - 37ms/step
# Epoch 125/150
# 181/181 - 7s - loss: 9.2830e-04 - 7s/epoch - 38ms/step
# Epoch 126/150
# 181/181 - 7s - loss: 0.0011 - 7s/epoch - 37ms/step
# Epoch 127/150
# 181/181 - 7s - loss: 9.5322e-04 - 7s/epoch - 38ms/step
# Epoch 128/150
# 181/181 - 7s - loss: 9.1167e-04 - 7s/epoch - 38ms/step
# Epoch 129/150
# 181/181 - 9s - loss: 9.0184e-04 - 9s/epoch - 49ms/step
# Epoch 130/150
# 181/181 - 7s - loss: 8.8229e-04 - 7s/epoch - 38ms/step
# Epoch 131/150
# 181/181 - 7s - loss: 8.7496e-04 - 7s/epoch - 36ms/step
# Epoch 132/150
# 181/181 - 7s - loss: 8.3954e-04 - 7s/epoch - 39ms/step
# Epoch 133/150
# 181/181 - 7s - loss: 8.1294e-04 - 7s/epoch - 36ms/step
# Epoch 134/150
# 181/181 - 7s - loss: 9.0817e-04 - 7s/epoch - 38ms/step
# Epoch 135/150
# 181/181 - 7s - loss: 8.2301e-04 - 7s/epoch - 37ms/step
# Epoch 136/150
# 181/181 - 7s - loss: 8.0814e-04 - 7s/epoch - 38ms/step
# Epoch 137/150
# 181/181 - 9s - loss: 8.6830e-04 - 9s/epoch - 50ms/step
# Epoch 138/150
# 181/181 - 7s - loss: 8.0691e-04 - 7s/epoch - 37ms/step
# Epoch 139/150
# 181/181 - 7s - loss: 9.8867e-04 - 7s/epoch - 38ms/step
# Epoch 140/150
# 181/181 - 7s - loss: 9.9632e-04 - 7s/epoch - 36ms/step
# Epoch 141/150
# 181/181 - 7s - loss: 8.2682e-04 - 7s/epoch - 39ms/step
# Epoch 142/150
# 181/181 - 7s - loss: 9.0233e-04 - 7s/epoch - 36ms/step
# Epoch 143/150
# 181/181 - 7s - loss: 8.1468e-04 - 7s/epoch - 38ms/step
# Epoch 144/150
# 181/181 - 7s - loss: 7.7275e-04 - 7s/epoch - 37ms/step
# Epoch 145/150
# 181/181 - 9s - loss: 8.6804e-04 - 9s/epoch - 50ms/step
# Epoch 146/150
# 181/181 - 7s - loss: 6.9397e-04 - 7s/epoch - 38ms/step
# Epoch 147/150
# 181/181 - 7s - loss: 7.8200e-04 - 7s/epoch - 37ms/step
# Epoch 148/150
# 181/181 - 7s - loss: 8.3104e-04 - 7s/epoch - 39ms/step
# Epoch 149/150
# 181/181 - 7s - loss: 8.8027e-04 - 7s/epoch - 37ms/step
# Epoch 150/150
# 181/181 - 7s - loss: 7.5708e-04 - 7s/epoch - 39ms/step

# %%
#轉為三維 再不是三圍的情況下
# trainX=np.reshape(trainX,(trainX.shape[0],trainX.shape[1],1))
# testX=np.reshape(testX,(testX.shape[0],testX.shape[1],1))

# %%
trainPre=model.predict(trainX)
testPre=model.predict(testX)
trainPre.shape
testPre.shape
# Out:
# 181/181 [==============================] - 3s 14ms/step
# 89/89 [==============================] - 1s 13ms/step
# (2846, 1)

# %%
trainPre=scalar2.inverse_transform(trainPre)
trainY=scalar2.inverse_transform([trainY])
testPre=scalar2.inverse_transform(testPre)
testY=scalar2.inverse_transform([testY])
print(trainPre.shape)
print(trainY.shape)
print(testPre.shape)
print(testY.shape)
# Out:
# (5782, 1)
# (1, 5782)
# (2846, 1)
# (1, 2846)

# %%
print(trainY.shape)
print(trainPre.shape)
print(trainY[0,1])
print(trainPre[1,0])
# Out:
# (1, 5782)
# (5782, 1)
# 2.0699998509781423
# 4.2165184

# %%
#MSE是均方根誤差 即平均誤差 會被平均除下去 所以數據多不代表誤差會增加
trainScore=math.sqrt(mean_squared_error(trainY[0,:],trainPre[:,0]))
print('Train Score:%.2f RMSE'%(trainScore))
testScore=math.sqrt(mean_squared_error(testY[0,:],testPre[:,0]))
print('Test Score:%.2f RMSE'%(testScore))
MAE=mean_absolute_error(testY[0,:],testPre[:,0])
print('Test Score:%.2f MAE'%(MAE))
# Out:
# Train Score:35.70 RMSE
# Test Score:114.25 RMSE
# Test Score:53.24 MAE

# %%
print(trainY[0,:])
print(trainPre[:,0].shape)
# Out:
# [2.15000019 2.06999985 2.05999993 ... 1.23999998 1.22000004 1.23999998]
# (5782,)

# %%
trainPredictplot=np.empty_like(scalar_dim)
#print(trainPredictplot)
trainPredictplot[:,:]=np.nan
#print(trainPredictplot)
trainPredictplot[look_back:len(trainPre)+look_back,:]=trainPre
print(trainPredictplot)
print(trainPredictplot.shape)
# Out:
# [[nan]
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  [nan]]
# (8640, 1)

# %%
testPredictPlot=np.empty_like(scalar_dim)
testPredictPlot[:,:]=np.NaN
testPredictPlot[len(trainPre)+(look_back*2)+1:len(dataset)-1,:]=testPre
print(testPredictPlot)
# Out:
# [[      nan]
#  [      nan]
#  [      nan]
#  ...
#  [292.423  ]
#  [613.68896]
#  [      nan]]

# %%
ground_truth=scalar2.inverse_transform(scalar_dim)
plt.plot(testY[0,:],label='Ground Truth')
plt.plot(testPre,label='Prediction(testing)')
plt.legend()
plt.show()

# %%
predict.my_self(testY[0,:],testPre[:,0],'TCN_test')
predict.score_calculation(testY[0,:],testPre[:,0])
predict.plot_pred(testY[0,:],testPre[:,0],'TCN_test')
predict.plot_residuals(testY[0,:],testPre[:,0],'TCN_test')
# Out:
# MAE: 53.24
# RMSE: 114.25
# R2 Score: 0.88
# MAE: 53.24
# RMSE: 114.25
# R2 Score: 0.88
# MAE: 53.24
# RMSE: 114.25
# R2 Score: 0.88

# %%
# predict.my_self(testY[0,:],testPre[:,0],'TCN_TPE')
# predict.score_calculation(testY[0,:],testPre[:,0])
# predict.plot_pred(testY[0,:],testPre[:,0],'TCN_TPE')
# predict.plot_residuals(testY[0,:],testPre[:,0],'TCN_TPE')

# %%
# predict.my_self(testY[0,:],testPre[:,0],'TCN')
# predict.score_calculation(testY[0,:],testPre[:,0])
# predict.plot_pred(testY[0,:],testPre[:,0],'TCN')
# predict.plot_residuals(testY[0,:],testPre[:,0],'TCN')

# %%
error=testY[0,:]-testPre[:,0]
error=abs(error)
print(error)
error=sorted(error)
print(error[int(len(error)/3)])
print(error[int(len(error)*2/3)])
# Out:
# [ 14.56370186  14.08139494  14.05531004 ... 100.41239501  52.47700274
#  248.02894946]
# 10.220493336169632
# 30.2657527923584
