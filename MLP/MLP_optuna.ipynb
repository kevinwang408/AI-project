# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import predict
import optuna

# %%
dataset=pd.read_csv('SolarPrediction_aligned_Sun.csv',engine='python',nrows=576*15)
dataset=dataset.drop("Data",axis=1)
dataset=dataset.drop("Time",axis=1)
# dataset=dataset.drop("TimeSunRise",axis=1)
# dataset=dataset.drop("TimeSunSet",axis=1)
target=dataset["Radiation"]
dataset.head(5)
# Out:
#    UNIXTime  Radiation  Temperature  Pressure  Humidity  \
# 0         8       2.58           51     30.43       103
# 1       310       2.83           51     30.43       103
# 2      1206       2.16           51     30.43       103
# 3      1505       2.21           51     30.43       103
# 4      1809       2.25           51     30.43       103
#
#    WindDirection(Degrees)  Speed  TimeSunRise  TimeSunSet
# 0                   77.27  11.25        22020       67080
# 1                  153.44   9.00        22020       67080
# 2                  142.04   7.87        22020       67080
# 3                  144.12  18.00        22020       67080
# 4                   67.42  11.25        22020       67080

# %%
dataset=dataset.values
dataset=dataset.astype('float32')
scalar1=MinMaxScaler(feature_range=(0,1))
scalar2=MinMaxScaler(feature_range=(0,1))
scalar_dim=dataset[:,1]
dataset=scalar1.fit_transform(dataset)

scalar_dim=scalar_dim.reshape(len(dataset),1)
print(scalar_dim)
scalar_dim=scalar2.fit_transform(scalar_dim)
print(scalar_dim)

train_size=int(len(dataset)*0.67)
test_size=len(dataset)- train_size
train,test=dataset[0:train_size,:],dataset[train_size:len(dataset),:]
# Out:
# [[  2.58]
#  [  2.83]
#  [  2.16]
#  ...
#  [344.9 ]
#  [365.66]
#  [355.57]]
# [[0.00089369]
#  [0.00104993]
#  [0.00063121]
#  ...
#  [0.21482898]
#  [0.2278031 ]
#  [0.22149728]]

# %%
def create_dataset(dataset,look_back):
    dataX,dataY=[],[]
    for i in range(len(dataset)-look_back-1):
        #a=dataset第0行i~i+look_back個
        a=dataset[i:(i+look_back),0:9]
        dataX.append(a)
        dataY.append(dataset[i+look_back,1])
    return np.array(dataX),np.array(dataY)

# %%
look_back=5
trainX,trainY=create_dataset(train,look_back)
testX,testY=create_dataset(test,look_back)

# %%
trainX=trainX.reshape(5782,45)
testX=testX.reshape(2846,45)
trainY=trainY.reshape(len(trainY),1)
testY=testY.reshape(len(testY),1)

# %%
def objective(trial):
    # 定義 MLPRegressor 的超參數範圍
    hidden_layer_sizes = (
        trial.suggest_int("n_layers", 1, 5),  # 隱藏層層數
        trial.suggest_int("n_units", 32, 256),  # 每個隱藏層的單位數
    )

    # 創建 MLPRegressor 模型
    mlp = MLPRegressor(
        hidden_layer_sizes=hidden_layer_sizes,
        max_iter=trial.suggest_int("max_iter", 100, 500),
        alpha=trial.suggest_float("alpha", 1e-5, 1e-1, log=True),
        random_state=42,
    )

    # 訓練模型
    mlp.fit(trainX, trainY)

    # 進行預測
    y_pred = mlp.predict(testX)
    

    # 計算均方誤差
    mse = mean_squared_error(testY, y_pred)

    return mse

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# 取得最佳超參數
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# 使用最佳超參數重新建立模型
best_mlp = MLPRegressor(
    hidden_layer_sizes=(best_params["n_layers"], best_params["n_units"]),
    max_iter=best_params["max_iter"],
    alpha=best_params["alpha"],
    random_state=42,
)

# 訓練最佳模型
best_mlp.fit(trainX, trainY)

# 最佳模型的預測
y_pred_best = best_mlp.predict(testX)

# 計算最佳模型的均方誤差
mse_best = mean_squared_error(testY, y_pred_best)
print("Best Model Mean Squared Error:", mse_best)
# Out:
# [I 2024-01-29 18:52:09,019] A new study created in memory with name: no-name-243aaa23-42c3-46a1-bed4-53f8a2551cb6
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:09,607] Trial 0 finished with value: 0.004921585321426392 and parameters: {'n_layers': 5, 'n_units': 67, 'max_iter': 353, 'alpha': 0.001803352399772248}. Best is trial 0 with value: 0.004921585321426392.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:10,277] Trial 1 finished with value: 0.0038803908973932266 and parameters: {'n_layers': 5, 'n_units': 161, 'max_iter': 293, 'alpha': 0.020007980627134575}. Best is trial 1 with value: 0.0038803908973932266.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:10,890] Trial 2 finished with value: 0.004533940460532904 and parameters: {'n_layers': 2, 'n_units': 122, 'max_iter': 410, 'alpha': 4.0302565308352194e-05}. Best is trial 1 with value: 0.0038803908973932266.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:11,515] Trial 3 finished with value: 0.00386705226264894 and parameters: {'n_layers': 4, 'n_units': 185, 'max_iter': 249, 'alpha': 0.030088955701365494}. Best is trial 3 with value: 0.00386705226264894.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:12,141] Trial 4 finished with value: 0.003706129267811775 and parameters: {'n_layers': 4, 'n_units': 160, 'max_iter': 367, 'alpha': 0.0009601041661523636}. Best is trial 4 with value: 0.003706129267811775.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:13,278] Trial 5 finished with value: 0.00398798193782568 and parameters: {'n_layers': 1, 'n_units': 126, 'max_iter': 314, 'alpha': 0.01622598741777453}. Best is trial 4 with value: 0.003706129267811775.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:13,704] Trial 6 finished with value: 0.0432434119284153 and parameters: {'n_layers': 1, 'n_units': 130, 'max_iter': 399, 'alpha': 0.0038090023623547123}. Best is trial 4 with value: 0.003706129267811775.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:14,025] Trial 7 finished with value: 0.0049410234205424786 and parameters: {'n_layers': 1, 'n_units': 40, 'max_iter': 435, 'alpha': 8.045549986078766e-05}. Best is trial 4 with value: 0.003706129267811775.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:14,596] Trial 8 finished with value: 0.004007397685199976 and parameters: {'n_layers': 5, 'n_units': 56, 'max_iter': 107, 'alpha': 0.06581837191237748}. Best is trial 4 with value: 0.003706129267811775.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:15,445] Trial 9 finished with value: 0.0035763464402407408 and parameters: {'n_layers': 5, 'n_units': 247, 'max_iter': 500, 'alpha': 0.0016736005294802968}. Best is trial 9 with value: 0.0035763464402407408.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:16,383] Trial 10 finished with value: 0.004043142776936293 and parameters: {'n_layers': 3, 'n_units': 255, 'max_iter': 498, 'alpha': 0.0002494850287270809}. Best is trial 9 with value: 0.0035763464402407408.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:17,197] Trial 11 finished with value: 0.0034783713053911924 and parameters: {'n_layers': 4, 'n_units': 248, 'max_iter': 203, 'alpha': 0.0003797590121274539}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:17,973] Trial 12 finished with value: 0.00395384943112731 and parameters: {'n_layers': 4, 'n_units': 256, 'max_iter': 150, 'alpha': 0.0003474445401608174}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:19,048] Trial 13 finished with value: 0.0037428312934935093 and parameters: {'n_layers': 3, 'n_units': 213, 'max_iter': 218, 'alpha': 1.0284769994329062e-05}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:19,760] Trial 14 finished with value: 0.003636681940406561 and parameters: {'n_layers': 4, 'n_units': 220, 'max_iter': 194, 'alpha': 0.004862410421081106}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:20,543] Trial 15 finished with value: 0.0036108442582190037 and parameters: {'n_layers': 5, 'n_units': 221, 'max_iter': 475, 'alpha': 0.0004728051088526938}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:21,260] Trial 16 finished with value: 0.004035172518342733 and parameters: {'n_layers': 4, 'n_units': 194, 'max_iter': 268, 'alpha': 8.360708753934868e-05}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:22,383] Trial 17 finished with value: 0.0039547039195895195 and parameters: {'n_layers': 3, 'n_units': 235, 'max_iter': 175, 'alpha': 0.004445661227959858}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:23,007] Trial 18 finished with value: 0.004662769380956888 and parameters: {'n_layers': 2, 'n_units': 86, 'max_iter': 137, 'alpha': 0.0009594093110604658}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:23,783] Trial 19 finished with value: 0.0037980270572006702 and parameters: {'n_layers': 5, 'n_units': 190, 'max_iter': 223, 'alpha': 0.0002360770388963643}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:24,688] Trial 20 finished with value: 0.0035653747618198395 and parameters: {'n_layers': 4, 'n_units': 240, 'max_iter': 322, 'alpha': 0.0020354398973939257}. Best is trial 11 with value: 0.0034783713053911924.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:25,667] Trial 21 finished with value: 0.0034769524354487658 and parameters: {'n_layers': 4, 'n_units': 239, 'max_iter': 315, 'alpha': 0.0022931745989755196}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:26,383] Trial 22 finished with value: 0.003533972194418311 and parameters: {'n_layers': 4, 'n_units': 232, 'max_iter': 338, 'alpha': 0.008237333228729039}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:27,238] Trial 23 finished with value: 0.004083996172994375 and parameters: {'n_layers': 3, 'n_units': 203, 'max_iter': 344, 'alpha': 0.008734684797174043}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:27,977] Trial 24 finished with value: 0.003568482119590044 and parameters: {'n_layers': 4, 'n_units': 232, 'max_iter': 283, 'alpha': 0.09072655470137918}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:28,677] Trial 25 finished with value: 0.004187234211713076 and parameters: {'n_layers': 2, 'n_units': 172, 'max_iter': 255, 'alpha': 0.009681385164068556}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:29,489] Trial 26 finished with value: 0.0035620820708572865 and parameters: {'n_layers': 4, 'n_units': 210, 'max_iter': 382, 'alpha': 0.0001277258945978363}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:30,461] Trial 27 finished with value: 0.004274243023246527 and parameters: {'n_layers': 3, 'n_units': 230, 'max_iter': 333, 'alpha': 0.0005545025802816915}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:31,160] Trial 28 finished with value: 0.00375546095892787 and parameters: {'n_layers': 3, 'n_units': 104, 'max_iter': 226, 'alpha': 0.003084364223451994}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:31,753] Trial 29 finished with value: 0.0036263754591345787 and parameters: {'n_layers': 4, 'n_units': 172, 'max_iter': 358, 'alpha': 0.007945622597622267}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:32,460] Trial 30 finished with value: 0.0036514305975288153 and parameters: {'n_layers': 5, 'n_units': 242, 'max_iter': 299, 'alpha': 0.0017066322116807218}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:33,232] Trial 31 finished with value: 0.003552542068064213 and parameters: {'n_layers': 4, 'n_units': 210, 'max_iter': 377, 'alpha': 0.00013201835193178742}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:33,802] Trial 32 finished with value: 0.0038416567258536816 and parameters: {'n_layers': 4, 'n_units': 222, 'max_iter': 429, 'alpha': 3.4599005480394755e-05}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:34,440] Trial 33 finished with value: 0.0042916713282465935 and parameters: {'n_layers': 5, 'n_units': 202, 'max_iter': 384, 'alpha': 0.0006508514238147629}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:35,154] Trial 34 finished with value: 0.0039797499775886536 and parameters: {'n_layers': 4, 'n_units': 256, 'max_iter': 309, 'alpha': 0.00019024769465408054}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:36,011] Trial 35 finished with value: 0.004102344159036875 and parameters: {'n_layers': 3, 'n_units': 178, 'max_iter': 280, 'alpha': 3.661547235143918e-05}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:36,673] Trial 36 finished with value: 0.0035602760035544634 and parameters: {'n_layers': 4, 'n_units': 227, 'max_iter': 348, 'alpha': 0.032390170916206266}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:37,378] Trial 37 finished with value: 0.003667759709060192 and parameters: {'n_layers': 4, 'n_units': 244, 'max_iter': 432, 'alpha': 1.7824583774371197e-05}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:38,043] Trial 38 finished with value: 0.0036867132876068354 and parameters: {'n_layers': 5, 'n_units': 143, 'max_iter': 369, 'alpha': 0.0011123621520238598}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:38,676] Trial 39 finished with value: 0.0035570787731558084 and parameters: {'n_layers': 4, 'n_units': 208, 'max_iter': 328, 'alpha': 0.016990504031932183}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:39,338] Trial 40 finished with value: 0.0042249467223882675 and parameters: {'n_layers': 5, 'n_units': 161, 'max_iter': 411, 'alpha': 8.103719651133493e-05}. Best is trial 21 with value: 0.0034769524354487658.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:40,070] Trial 41 finished with value: 0.00326302251778543 and parameters: {'n_layers': 4, 'n_units': 210, 'max_iter': 328, 'alpha': 0.0201293522716579}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:40,727] Trial 42 finished with value: 0.0037138182669878006 and parameters: {'n_layers': 4, 'n_units': 195, 'max_iter': 393, 'alpha': 0.03658004894357274}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:41,309] Trial 43 finished with value: 0.003728926880285144 and parameters: {'n_layers': 4, 'n_units': 215, 'max_iter': 312, 'alpha': 0.010669520601684685}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:42,118] Trial 44 finished with value: 0.004116885829716921 and parameters: {'n_layers': 3, 'n_units': 241, 'max_iter': 365, 'alpha': 0.0058554041790075985}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:42,763] Trial 45 finished with value: 0.003555821254849434 and parameters: {'n_layers': 4, 'n_units': 250, 'max_iter': 248, 'alpha': 0.0024117728408104295}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:43,391] Trial 46 finished with value: 0.003985436633229256 and parameters: {'n_layers': 3, 'n_units': 144, 'max_iter': 297, 'alpha': 0.020733231141566697}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:44,096] Trial 47 finished with value: 0.0052729398012161255 and parameters: {'n_layers': 2, 'n_units': 228, 'max_iter': 340, 'alpha': 0.05729233058222441}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:44,673] Trial 48 finished with value: 0.0036166817881166935 and parameters: {'n_layers': 4, 'n_units': 199, 'max_iter': 459, 'alpha': 0.00012260873863840626}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-01-29 18:52:45,329] Trial 49 finished with value: 0.0037570807617157698 and parameters: {'n_layers': 5, 'n_units': 187, 'max_iter': 412, 'alpha': 0.00034549057104432776}. Best is trial 41 with value: 0.00326302251778543.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1617: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Hyperparameters: {'n_layers': 4, 'n_units': 210, 'max_iter': 328, 'alpha': 0.0201293522716579}
# Best Model Mean Squared Error: 0.0032630225
