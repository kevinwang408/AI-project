# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pandas import read_csv
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import predict
import optuna

# %%
dataset=pd.read_csv('SolarPrediction_aligned_Sun.csv',engine='python',nrows=576*15)
dataset=dataset.drop("Data",axis=1)
dataset=dataset.drop("Time",axis=1)
target=dataset["Radiation"]
#target=dataset["Radiation"]
dataset.head(5)
# Out:
#    UNIXTime  Radiation  Temperature  Pressure  Humidity  \
# 0         8       2.58           51     30.43       103
# 1       310       2.83           51     30.43       103
# 2      1206       2.16           51     30.43       103
# 3      1505       2.21           51     30.43       103
# 4      1809       2.25           51     30.43       103
#
#    WindDirection(Degrees)  Speed  TimeSunRise  TimeSunSet
# 0                   77.27  11.25        22020       67080
# 1                  153.44   9.00        22020       67080
# 2                  142.04   7.87        22020       67080
# 3                  144.12  18.00        22020       67080
# 4                   67.42  11.25        22020       67080

# %%
dataset=dataset.values
target=target.values

# %%
dataset[:,1]=dataset[:,8]
dataset[:,8]=target[:]
#print(dataset[0,:])
# print(temp1)
# print(temp2)
#target=target.values
#target=target.values

# %%
def create_dataset(dataset,look_back):
    dataX,dataY=[],[]
    for i in range(len(dataset)-look_back-1):
        #a=dataset第0行i~i+look_back個
        a=dataset[i:(i+look_back),0:9]
        dataX.append(a)
        dataY.append(dataset[i+look_back,8])
    return np.array(dataX),np.array(dataY)

# %%
train_size=int(len(dataset)*0.67)
test_size=len(dataset)- train_size
train,test=dataset[0:train_size,:],dataset[train_size:len(dataset),:]

# %%
trainX,trainY=create_dataset(train,5)
testX,testY=create_dataset(test,5)
print("train_x: ",trainX.shape)
print("train y: ",trainY.shape)
print("testX: ",testX.shape)
print(trainX[0,:,:])
print(trainY[0])
trainX=trainX.reshape(5782,45)
testX=testX.reshape(2846,45)
trainY=trainY.reshape(len(trainY),1)
testY=testY.reshape(len(testY),1)
print(trainX.shape)
print(trainX[0,:])
# Out:
# train_x:  (5782, 5, 9)
# train y:  (5782,)
# testX:  (2846, 5, 9)
# [[8.0000e+00 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 7.7270e+01
#   1.1250e+01 2.2020e+04 2.5800e+00]
#  [3.1000e+02 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 1.5344e+02
#   9.0000e+00 2.2020e+04 2.8300e+00]
#  [1.2060e+03 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 1.4204e+02
#   7.8700e+00 2.2020e+04 2.1600e+00]
#  [1.5050e+03 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 1.4412e+02
#   1.8000e+01 2.2020e+04 2.2100e+00]
#  [1.8090e+03 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 6.7420e+01
#   1.1250e+01 2.2020e+04 2.2500e+00]]
# 2.15
# (5782, 45)
# [8.0000e+00 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 7.7270e+01
#  1.1250e+01 2.2020e+04 2.5800e+00 3.1000e+02 6.7080e+04 5.1000e+01
#  3.0430e+01 1.0300e+02 1.5344e+02 9.0000e+00 2.2020e+04 2.8300e+00
#  1.2060e+03 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 1.4204e+02
#  7.8700e+00 2.2020e+04 2.1600e+00 1.5050e+03 6.7080e+04 5.1000e+01
#  3.0430e+01 1.0300e+02 1.4412e+02 1.8000e+01 2.2020e+04 2.2100e+00
#  1.8090e+03 6.7080e+04 5.1000e+01 3.0430e+01 1.0300e+02 6.7420e+01
#  1.1250e+01 2.2020e+04 2.2500e+00]

# %%
np.random.seed(7)


dataset=dataset.astype('float32')
target=target.astype('float32')

scalar1=MinMaxScaler(feature_range=(0,1))
scalar2=MinMaxScaler(feature_range=(0,1))
scalar3=MinMaxScaler(feature_range=(0,1))
scalar4=MinMaxScaler(feature_range=(0,1))
#scalar_dim=dataset[:,1]

#target=dataset[:,1]
trainX=scalar1.fit_transform(trainX)
testX=scalar2.fit_transform(testX)
trainY=scalar3.fit_transform(trainY)
testY=scalar4.fit_transform(testY)
#target=target.reshape(len(target),1)
# target=scalar2.fit_transform(target)

# %%
def objective(trial):
    # 定義 DecisionTreeRegressor 的超參數範圍
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 20),
        'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2', None])
    }

    # 創建 DecisionTreeRegressor 模型
    model = DecisionTreeRegressor(**params)
    model.fit(trainX, trainY)
    y_pred = model.predict(testX)
    # 使用交叉驗證評估模型性能
    score =mean_squared_error(testY,y_pred)

    return score

# %%
# 使用 Optuna 調整超參數
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)

# 取得最佳超參數
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# [I 2024-01-30 19:01:40,429] A new study created in memory with name: no-name-9f9a2c0c-7692-4063-b944-4db549a1ce41
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:40,498] Trial 0 finished with value: 0.005065794844515677 and parameters: {'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 19, 'max_features': 'auto'}. Best is trial 0 with value: 0.005065794844515677.
# [I 2024-01-30 19:01:40,523] Trial 1 finished with value: 0.014397264138368707 and parameters: {'max_depth': 19, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 0 with value: 0.005065794844515677.
# [I 2024-01-30 19:01:40,579] Trial 2 finished with value: 0.005011484519329373 and parameters: {'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 16, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:40,693] Trial 3 finished with value: 0.005468244446451474 and parameters: {'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 11, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:40,715] Trial 4 finished with value: 0.011342491994606308 and parameters: {'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:40,730] Trial 5 finished with value: 0.0067241716110754655 and parameters: {'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:40,744] Trial 6 finished with value: 0.009678088508957296 and parameters: {'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.005011484519329373.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:40,860] Trial 7 finished with value: 0.014298786673120558 and parameters: {'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:40,896] Trial 8 finished with value: 0.0054780494264149845 and parameters: {'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:41,004] Trial 9 finished with value: 0.005406850383269694 and parameters: {'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 12, 'max_features': 'auto'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,056] Trial 10 finished with value: 0.005478049426414976 and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 19, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:41,141] Trial 11 finished with value: 0.005063658335409142 and parameters: {'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 20, 'max_features': 'auto'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,167] Trial 12 finished with value: 0.009363058466200272 and parameters: {'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 16, 'max_features': 'log2'}. Best is trial 2 with value: 0.005011484519329373.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:41,236] Trial 13 finished with value: 0.005011484519329373 and parameters: {'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 16, 'max_features': 'auto'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,303] Trial 14 finished with value: 0.005189083737952197 and parameters: {'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 15, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# C:\Users\wang8\anaconda3\lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# [I 2024-01-30 19:01:41,417] Trial 15 finished with value: 0.0053818387459104765 and parameters: {'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 13, 'max_features': 'auto'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,525] Trial 16 finished with value: 0.0066955959782936825 and parameters: {'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': None}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,549] Trial 17 finished with value: 0.0068679966728057455 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 17, 'max_features': 'log2'}. Best is trial 2 with value: 0.005011484519329373.
# [I 2024-01-30 19:01:41,650] Trial 18 finished with value: 0.005386394627316096 and parameters: {'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf':